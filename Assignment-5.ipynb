# %% [markdown]
# <a href="https://colab.research.google.com/github/raghavendra-kashwajula/Reinforcement_Learning/blob/main/Assignment-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name):
    env = gym.make(env_name)
    state, info = env.reset()

    total_reward = 0
    steps = 0

    print("\nEnvironment:", env_name)
    print("Initial State:", state)
    print("Action Space:", env.action_space)

    while True:
        action = env.action_space.sample()
        next_state, reward, terminated, truncated, info = env.step(action)

        total_reward += reward
        steps += 1
        state = next_state

        if terminated or truncated:
            break

    average_reward = total_reward / steps

    print("Total Steps:", steps)
    print("Total Reward:", total_reward)
    print("Average Reward:", average_reward)

    env.close()

random_agent("CartPole-v1")
random_agent("MountainCar-v0")
random_agent("FrozenLake-v1")
# Out:
# Environment: CartPole-v1
# Initial State: [-0.00329839 -0.04635621  0.02968556  0.03107036]
# Action Space: Discrete(2)
# Total Steps: 9
# Total Reward: 9.0
# Average Reward: 1.0
#
# Environment: MountainCar-v0
# Initial State: [-0.55416983  0.        ]
# Action Space: Discrete(3)
# Total Steps: 200
# Total Reward: -200.0
# Average Reward: -1.0
#
# Environment: FrozenLake-v1
# Initial State: 0
# Action Space: Discrete(4)
# Total Steps: 13
# Total Reward: 0
# Average Reward: 0.0
